# %% [markdown]
# Source Problem: [Print Function](https://www.hackerrank.com/challenges/python-print/problem?isFullScreen=true)

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i+1, end="")
# Out:
# 3
# 123
