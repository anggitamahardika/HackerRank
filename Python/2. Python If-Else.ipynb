# %% [markdown]
# Source Problem: [Python If-Else](https://www.hackerrank.com/challenges/py-if-else/problem?isFullScreen=true)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if (n%2 == 0):
        if ((n >= 2 and n < 5) or (n > 20)):
            print("Not Weird")
        elif (n >= 6 and n <= 20):
            print("Weird")
    else:
        print ("Weird")
# Out:
# 3
# Weird
