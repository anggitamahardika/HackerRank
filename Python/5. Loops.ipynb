# %% [markdown]
# Source Problem: [Loops](https://www.hackerrank.com/challenges/python-loops?isFullScreen=true)

# %%
if __name__ == '__main__':
    n = int(input())
    i=0
    while i < n:
        print(i**2)
        i+=1;
# Out:
# 5
# 0
# 1
# 4
# 9
# 16
