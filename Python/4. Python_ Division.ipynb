# %% [markdown]
# Source Problem: [Python: Division](https://www.hackerrank.com/challenges/python-division/problem?isFullScreen=true)

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
# 4
# 3
# 1
# 1.3333333333333333
