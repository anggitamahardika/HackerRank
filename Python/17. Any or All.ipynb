# %% [markdown]
# Source Problem: [Any or All](https://www.hackerrank.com/challenges/any-or-all/problem?isFullScreen=true)

# %%
n = int(input())
list_n = input().split()
print(all( int(i) > 0 for i in list_n) and any( i == i[::-1] for i in list_n))
# Out:
# 5
# 12 9 61 5 14
# True
