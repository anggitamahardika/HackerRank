# %% [markdown]
# Problem Source: [Python Evaluation](https://www.hackerrank.com/challenges/python-eval/problem?isFullScreen=true)

# %%
from __future__ import print_function

eval(input())
# Out:
# print(2 + 3)
# 5
